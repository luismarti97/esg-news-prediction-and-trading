# %% [markdown]
# # Inference of ESG Multiclass Classification using Fine-tuned RoBERTa
#
# In this notebook, we perform the inference stage for the previously fine-tuned RoBERTa model on ESG news classification into three categories: Environmental, Social, and Governance.
#
# The main objective is to apply the trained multiclass classification model to a large dataset of ESG-related news, in order to automatically predict the ESG category associated with each news article. This process will allow us to structure and label a large amount of textual information for subsequent analysis.
#
# The inference pipeline includes:
# - Loading the fine-tuned RoBERTa model with previously saved weights.
# - Preprocessing the news dataset (title + content) for tokenization.
# - Applying the trained model to predict the ESG category for each sample.
# - Storing the resulting predictions for later usage in ESG scoring models and further investment algorithms.
#
# This inference step is critical to transform raw news data into structured ESG signals that can be exploited in decision-making systems, particularly in the context of ESG-focused investment strategies.

# %%
import torch
import torch.nn as nn
from transformers import RobertaModel
import numpy as np
from tqdm import tqdm
from transformers import RobertaTokenizer
from torch.utils.data import Dataset, DataLoader

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/MIAX/TRABAJO FINAL DE MASTER DEFINITIVO/total_news_esg_filtered.csv'
df_trainning = pd.read_csv(path)
df_trainning
# Out:
# <ipython-input-6-60e0852d7363>:2: DtypeWarning: Columns (5,8,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_trainning = pd.read_csv(path)
#           id           Publication Date  \
# 0        1.0  2024-12-09 08:41:30+00:00
# 1        2.0  2024-07-23 17:13:37+00:00
# 2        3.0  2024-07-18 14:19:34+00:00
# 3        4.0  2024-07-18 14:04:50+00:00
# 4        5.0  2024-05-27 07:03:20+00:00
# ...      ...                        ...
# 1070256  NaN        2025-03-21 16:21:09
# 1070257  NaN        2025-03-21 20:20:23
# 1070258  NaN        2025-03-22 07:30:00
# 1070259  NaN        2025-03-22 11:00:00
# 1070260  NaN        2025-03-23 12:06:00
#
#                                                      title  \
# 0                         Call of Duty: Black Ops 6 Review
# 1        Xbox Celebrates the Release of Modern Warfare ...
# 2        How ToxMod's AI impacted toxicity in Call of D...
# 3        How ToxMod's AI impacted toxicity in Call of D...
# 4        Meta, Activision Sued by Families of Uvalde Sc...
# ...                                                    ...
# 1070256  Nike shares tumble as tariff concerns shake in...
# 1070257          Making Sense of Early Q1 Earnings Reports
# 1070258  Why Is Nike Stock Falling, and Should Investor...
# 1070259  Will Nike Investors' Frustrations End Anytime ...
# 1070260  Buying the Dip in Nike's Stock Could Be a Mistake
#
#                                                    content  \
# 0        The last year or so wasn’t the kindest to Call...
# 1        Recently, many rumors were running on the inte...
# 2        It's no secret Call of Duty has toxic players....
# 3        It's no secret Call of Duty has toxic players....
# 4        In the wake of the tragic shooting at Robb Ele...
# ...                                                    ...
# 1070256  Shares in NIKE, Inc. (NYSE: NKE) are falling i...
# 1070257  We have been seeing some of the early Q1 resul...
# 1070258  Nike's (NKE -5.37%) sales are declining in eve...
# 1070259  If you're a Nike (NKE -5.37%) investor, it wou...
# 1070260  Nike (NKE -5.37%) beat earnings and revenue ex...
#
#                             source sentiment_body  sentiment_body_score  \
# 0                        Eggplante       positive                  0.98
# 1                         Cinelinx       positive                  0.90
# 2                            DNyuz        neutral                  0.48
# 3                    Allusanewshub        neutral                  0.54
# 4                       Tech Times        neutral                  0.92
# ...                            ...            ...                   ...
# 1070256               Fast Company            NaN                   NaN
# 1070257  Zacks Investment Research            NaN                   NaN
# 1070258            The Motley Fool            NaN                   NaN
# 1070259            The Motley Fool            NaN                   NaN
# 1070260            The Motley Fool            NaN                   NaN
#
#             company         sector  \
# 0        activision  Communication
# 1        activision  Communication
# 2        activision  Communication
# 3        activision  Communication
# 4        activision  Communication
# ...             ...            ...
# 1070256        nike            NaN
# 1070257        nike            NaN
# 1070258        nike            NaN
# 1070259        nike            NaN
# 1070260        nike            NaN
#
#                                                        url ticker description  \
# 0                                                      NaN   ATVI         NaN
# 1                                                      NaN   ATVI         NaN
# 2                                                      NaN   ATVI         NaN
# 3                                                      NaN   ATVI         NaN
# 4                                                      NaN   ATVI         NaN
# ...                                                    ...    ...         ...
# 1070256  https://www.fastcompany.com/91303743/nike-shar...    NKE         NaN
# 1070257  https://www.zacks.com/commentary/2433762/makin...    NKE         NaN
# 1070258  https://www.fool.com/investing/2025/03/22/why-...    NKE         NaN
# 1070259  https://www.fool.com/investing/2025/03/22/will...    NKE         NaN
# 1070260  https://www.fool.com/investing/2025/03/23/buyi...    NKE         NaN
#
#                                                       text  esg_pred
# 0        Call of Duty: Black Ops 6 Review. The last yea...         0
# 1        Xbox Celebrates the Release of Modern Warfare ...         0
# 2        How ToxMod's AI impacted toxicity in Call of D...         1
# 3        How ToxMod's AI impacted toxicity in Call of D...         1
# 4        Meta, Activision Sued by Families of Uvalde Sc...         1
# ...                                                    ...       ...
# 1070256  Nike shares tumble as tariff concerns shake in...         1
# 1070257  Making Sense of Early Q1 Earnings Reports. We ...         0
# 1070258  Why Is Nike Stock Falling, and Should Investor...         0
# 1070259  Will Nike Investors' Frustrations End Anytime ...         0
# 1070260  Buying the Dip in Nike's Stock Could Be a Mist...         0
#
# [1070261 rows x 14 columns]

# %%
df_trainning = df_trainning[df_trainning['esg_pred'] == 1].copy()
df_trainning
# Out:
#            id           Publication Date  \
# 2         3.0  2024-07-18 14:19:34+00:00
# 3         4.0  2024-07-18 14:04:50+00:00
# 4         5.0  2024-05-27 07:03:20+00:00
# 7         8.0  2024-04-02 15:34:29+00:00
# 10       11.0  2024-01-24 03:28:56+00:00
# ...       ...                        ...
# 1070247   NaN        2025-03-21 10:50:51
# 1070249   NaN        2025-03-21 11:19:37
# 1070250   NaN        2025-03-21 11:20:15
# 1070253   NaN        2025-03-21 12:31:54
# 1070256   NaN        2025-03-21 16:21:09
#
#                                                      title  \
# 2        How ToxMod's AI impacted toxicity in Call of D...
# 3        How ToxMod's AI impacted toxicity in Call of D...
# 4        Meta, Activision Sued by Families of Uvalde Sc...
# 7        Federal racial discrimination lawsuit against ...
# 10       Activision Will Pay $50 Million to Settle Work...
# ...                                                    ...
# 1070247  Nike is starting to show green-shoots with inn...
# 1070249  Nike Stock Plummets on Dismal Forecast, Bear N...
# 1070250  Nike Turnaround Hits Snags Amid Inventory Rese...
# 1070253                Why Nike Stock Got Tripped Up Today
# 1070256  Nike shares tumble as tariff concerns shake in...
#
#                                                    content  \
# 2        It's no secret Call of Duty has toxic players....
# 3        It's no secret Call of Duty has toxic players....
# 4        In the wake of the tragic shooting at Robb Ele...
# 7        'In Tesla's narrative, the agencies learned no...
# 10       Activision Blizzard will pay roughly $50 milli...
# ...                                                    ...
# 1070247  Andrea Andreeva, Piper Sandler analyst, joins ...
# 1070249  Brushing off a fiscal third-quarter earnings a...
# 1070250  Nike's turnaround effort is facing challenges ...
# 1070253  Shares of Nike (NKE -5.16%) fell Friday mornin...
# 1070256  Shares in NIKE, Inc. (NYSE: NKE) are falling i...
#
#                                 source sentiment_body  sentiment_body_score  \
# 2                                DNyuz        neutral                  0.48
# 3                        Allusanewshub        neutral                  0.54
# 4                           Tech Times        neutral                  0.92
# 7                          Head Topics       negative                  0.41
# 10                          Mytimesnow       positive                  0.64
# ...                                ...            ...                   ...
# 1070247                CNBC Television            NaN                   NaN
# 1070249            Schaeffers Research            NaN                   NaN
# 1070250  Bloomberg Markets and Finance            NaN                   NaN
# 1070253                The Motley Fool            NaN                   NaN
# 1070256                   Fast Company            NaN                   NaN
#
#             company         sector  \
# 2        activision  Communication
# 3        activision  Communication
# 4        activision  Communication
# 7        activision  Communication
# 10       activision  Communication
# ...             ...            ...
# 1070247        nike            NaN
# 1070249        nike            NaN
# 1070250        nike            NaN
# 1070253        nike            NaN
# 1070256        nike            NaN
#
#                                                        url ticker description  \
# 2                                                      NaN   ATVI         NaN
# 3                                                      NaN   ATVI         NaN
# 4                                                      NaN   ATVI         NaN
# 7                                                      NaN   ATVI         NaN
# 10                                                     NaN   ATVI         NaN
# ...                                                    ...    ...         ...
# 1070247        https://www.youtube.com/watch?v=yrwUTpiLvsI    NKE         NaN
# 1070249  https://www.schaeffersresearch.com/content/new...    NKE         NaN
# 1070250        https://www.youtube.com/watch?v=T4MRIaMz2ks    NKE         NaN
# 1070253  https://www.fool.com/investing/2025/03/21/why-...    NKE         NaN
# 1070256  https://www.fastcompany.com/91303743/nike-shar...    NKE         NaN
#
#                                                       text  esg_pred
# 2        How ToxMod's AI impacted toxicity in Call of D...         1
# 3        How ToxMod's AI impacted toxicity in Call of D...         1
# 4        Meta, Activision Sued by Families of Uvalde Sc...         1
# 7        Federal racial discrimination lawsuit against ...         1
# 10       Activision Will Pay $50 Million to Settle Work...         1
# ...                                                    ...       ...
# 1070247  Nike is starting to show green-shoots with inn...         1
# 1070249  Nike Stock Plummets on Dismal Forecast, Bear N...         1
# 1070250  Nike Turnaround Hits Snags Amid Inventory Rese...         1
# 1070253  Why Nike Stock Got Tripped Up Today. Shares of...         1
# 1070256  Nike shares tumble as tariff concerns shake in...         1
#
# [431220 rows x 14 columns]

# %%
class RoBERTaClass(nn.Module):
    def __init__(self):
        super(RoBERTaClass, self).__init__()
        self.roberta = RobertaModel.from_pretrained('roberta-base', return_dict=True)
        self.dropout = nn.Dropout(0.3)
        self.out = nn.Linear(768, 3)

    def forward(self, input_ids, attention_mask):
        output = self.roberta(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = self.dropout(output.pooler_output)
        return self.out(pooled_output)

ruta_pesos = "/content/drive/MyDrive/MIAX/TRABAJO FINAL DE MASTER DEFINITIVO/type_esg_model_weights.pt"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = RoBERTaClass()
model.load_state_dict(torch.load(ruta_pesos, map_location=device))
model.to(device)
model.eval()
# Out:
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# RoBERTaClass(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.3, inplace=False)
#   (out): Linear(in_features=768, out_features=3, bias=True)
# )

# %%
df_filtered = df_trainning[['text']]

# %%
class InferenceDataset(Dataset):
    def __init__(self, texts, tokenizer, max_len=256):
        self.texts = texts
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])
        encoded = tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        return {
            'input_ids': encoded['input_ids'].squeeze(0),
            'attention_mask': encoded['attention_mask'].squeeze(0)
        }

# %%
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
dataset = InferenceDataset(df_filtered['text'].tolist(), tokenizer, max_len=256)
dataloader = DataLoader(dataset, batch_size=64)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
def infer_model(model, dataloader, device):
    model.eval()
    predictions = []

    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Clasificando noticias"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)

            outputs = model(input_ids, attention_mask)
            _, preds = torch.max(outputs, dim=1)
            predictions.extend(preds.cpu().numpy())

    return np.array(predictions)

# %%
preds = infer_model(model, dataloader, device)
# Out:
# Clasificando noticias: 100%|██████████| 6738/6738 [45:34<00:00,  2.46it/s]

# %%
df_filtered['esg_type'] = preds
# Out:
# <ipython-input-14-79b81a5bc867>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['esg_type'] = preds

# %%
df_filtered['esg_type'].value_counts()
# Out:
# esg_type
# 2    169286
# 1    151232
# 0    110702
# Name: count, dtype: int64

# %%
df_trainning['esg_type'] = preds

# %%
conteo_por_empresa = df_trainning.groupby(['company', 'esg_type']).size().unstack(fill_value=0)
conteo_por_empresa.columns = ['Environmental (0)', 'Social (1)', 'Governance (2)']

# %%
nombres_equivalentes = {
    "amex": "american express",
    "conoco philips": "conocophillips",
    "conoco": "conocophillips",
    "cvs health": "cvs",
    "jhonson and jhonson": "johnson & johnson",
    "j&j": "johnson & johnson",
    "jp morgan": "jpmorgan",
    "the walt disney company": "disney",
    "unitedhealth": "united healthcare",
    "valero energy": "valero",
    "goldman": "goldman sachs"
}
df_trainning['company'] = df_trainning['company'].replace(nombres_equivalentes)

# %%
conteo_por_empresa = df_trainning.groupby(['company', 'esg_type']).size().unstack(fill_value=0)
conteo_por_empresa.columns = ['Environmental (0)', 'Social (1)', 'Governance (2)']
conteo_por_empresa
# Out:
#                     Environmental (0)  Social (1)  Governance (2)
# company
# abbvie                             50         748             321
# activision                         19        1130            2027
# amazon                          14159       20989           13213
# american express                  316         963             773
# apple                            9683       19861           25152
# chevron                          6169         766            2779
# comcast                           328        1206            1084
# conocophillips                   6960         261             953
# cvs                               301        4543            1324
# disney                           1261        5645            2315
# exxon                            8935         933            3753
# general motors                   8225        4319            4451
# goldman sachs                    2034        3699            6185
# google                           7565       14194           16826
# johnson & johnson                 259        7615            1676
# jpmorgan                         1547        1206            3137
# marathon petroleum                926         110             142
# mcdonalds                        1936        5471             752
# microsoft                        2956       10557           25719
# morgan stanley                   1958        1379            3289
# netflix                          1309        5785            2054
# nike                             1745        4900            1738
# nvidia                            960         455            3457
# pfizer                            447        8229            2092
# starbucks                        1675        9118            2044
# tesla                           25654        9383           32082
# the home depot                    614         961             538
# united healthcare                 116        2428            1961
# valero                            674          17             196
# verizon                           920        1452            2569
# wells fargo                       804        2071            3917

# %%
path = '/content/drive/MyDrive/MIAX/TRABAJO FINAL DE MASTER DEFINITIVO/news_second_classified.csv'
df_trainning.to_csv(path, index=False)

# %%
df_trainning
# Out:
#            id           Publication Date  \
# 2         3.0  2024-07-18 14:19:34+00:00
# 3         4.0  2024-07-18 14:04:50+00:00
# 4         5.0  2024-05-27 07:03:20+00:00
# 7         8.0  2024-04-02 15:34:29+00:00
# 10       11.0  2024-01-24 03:28:56+00:00
# ...       ...                        ...
# 1070247   NaN        2025-03-21 10:50:51
# 1070249   NaN        2025-03-21 11:19:37
# 1070250   NaN        2025-03-21 11:20:15
# 1070253   NaN        2025-03-21 12:31:54
# 1070256   NaN        2025-03-21 16:21:09
#
#                                                      title  \
# 2        How ToxMod's AI impacted toxicity in Call of D...
# 3        How ToxMod's AI impacted toxicity in Call of D...
# 4        Meta, Activision Sued by Families of Uvalde Sc...
# 7        Federal racial discrimination lawsuit against ...
# 10       Activision Will Pay $50 Million to Settle Work...
# ...                                                    ...
# 1070247  Nike is starting to show green-shoots with inn...
# 1070249  Nike Stock Plummets on Dismal Forecast, Bear N...
# 1070250  Nike Turnaround Hits Snags Amid Inventory Rese...
# 1070253                Why Nike Stock Got Tripped Up Today
# 1070256  Nike shares tumble as tariff concerns shake in...
#
#                                                    content  \
# 2        It's no secret Call of Duty has toxic players....
# 3        It's no secret Call of Duty has toxic players....
# 4        In the wake of the tragic shooting at Robb Ele...
# 7        'In Tesla's narrative, the agencies learned no...
# 10       Activision Blizzard will pay roughly $50 milli...
# ...                                                    ...
# 1070247  Andrea Andreeva, Piper Sandler analyst, joins ...
# 1070249  Brushing off a fiscal third-quarter earnings a...
# 1070250  Nike's turnaround effort is facing challenges ...
# 1070253  Shares of Nike (NKE -5.16%) fell Friday mornin...
# 1070256  Shares in NIKE, Inc. (NYSE: NKE) are falling i...
#
#                                 source sentiment_body  sentiment_body_score  \
# 2                                DNyuz        neutral                  0.48
# 3                        Allusanewshub        neutral                  0.54
# 4                           Tech Times        neutral                  0.92
# 7                          Head Topics       negative                  0.41
# 10                          Mytimesnow       positive                  0.64
# ...                                ...            ...                   ...
# 1070247                CNBC Television            NaN                   NaN
# 1070249            Schaeffers Research            NaN                   NaN
# 1070250  Bloomberg Markets and Finance            NaN                   NaN
# 1070253                The Motley Fool            NaN                   NaN
# 1070256                   Fast Company            NaN                   NaN
#
#             company         sector  \
# 2        activision  Communication
# 3        activision  Communication
# 4        activision  Communication
# 7        activision  Communication
# 10       activision  Communication
# ...             ...            ...
# 1070247        nike            NaN
# 1070249        nike            NaN
# 1070250        nike            NaN
# 1070253        nike            NaN
# 1070256        nike            NaN
#
#                                                        url ticker description  \
# 2                                                      NaN   ATVI         NaN
# 3                                                      NaN   ATVI         NaN
# 4                                                      NaN   ATVI         NaN
# 7                                                      NaN   ATVI         NaN
# 10                                                     NaN   ATVI         NaN
# ...                                                    ...    ...         ...
# 1070247        https://www.youtube.com/watch?v=yrwUTpiLvsI    NKE         NaN
# 1070249  https://www.schaeffersresearch.com/content/new...    NKE         NaN
# 1070250        https://www.youtube.com/watch?v=T4MRIaMz2ks    NKE         NaN
# 1070253  https://www.fool.com/investing/2025/03/21/why-...    NKE         NaN
# 1070256  https://www.fastcompany.com/91303743/nike-shar...    NKE         NaN
#
#                                                       text  esg_pred  esg_type
# 2        How ToxMod's AI impacted toxicity in Call of D...         1         1
# 3        How ToxMod's AI impacted toxicity in Call of D...         1         1
# 4        Meta, Activision Sued by Families of Uvalde Sc...         1         1
# 7        Federal racial discrimination lawsuit against ...         1         1
# 10       Activision Will Pay $50 Million to Settle Work...         1         1
# ...                                                    ...       ...       ...
# 1070247  Nike is starting to show green-shoots with inn...         1         2
# 1070249  Nike Stock Plummets on Dismal Forecast, Bear N...         1         2
# 1070250  Nike Turnaround Hits Snags Amid Inventory Rese...         1         2
# 1070253  Why Nike Stock Got Tripped Up Today. Shares of...         1         2
# 1070256  Nike shares tumble as tariff concerns shake in...         1         2
#
# [431220 rows x 15 columns]
